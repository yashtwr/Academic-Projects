# %% [markdown]
# # Question 1. Data Exploration
# ## [CM2] Visualization using Pair Plot

# %% [markdown]
# Importing all necessary libraries.

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Iris Dataset

# %%
df_iris = pd.read_csv("cleaned_data_iris.csv")
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0      5.045070     2.508203      3.018024     1.164924  Iris-versicolor
# 1      6.325517     2.115481      4.542052     1.413651  Iris-versicolor
# 2      5.257497     3.814303      1.470660     0.395348      Iris-setosa
# 3      6.675168     3.201700      5.785461     2.362764   Iris-virginica
# 4      5.595237     2.678166      4.077750     1.369266  Iris-versicolor

# %%
sns.pairplot(df_iris,hue='species')

# %% [markdown]
# <b> From the Iris data correlation graphs we can observe various correlation coefficients amongst the dataset features in the form of scatter plots. </b>

# %% [markdown]
# # Heart Disease Dataset

# %%
df_heart = pd.read_csv('heart_disease_cleaned.csv')

# %% [markdown]
# <b> Checking correlation values to find the strongly related features in the dataset </b>

# %%
#Heat Map
plt.figure(figsize=(15,10))
sns.heatmap(df_heart.corr(),center=0,annot=True, linewidths=.5, cmap = "Pastel1_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  From the Heart data Heat map we can observe various correlation coefficients amongst the dataset features. In our case, <b> the colour Green shows a strong negative correlation </b> between the features where as the colour<b> Gray indicates a strong positive correlation. </b>

# %% [markdown]
# The pairs of features <b> "slope" & "thalach", "exang" & "oldpeak", "Thalach" & "cp" </b> have a correlation coefficient of "0.44", "0.29", and "0.27" respectively which implies that the pair have a <b> strong correlation between them. </b>

# %% [markdown]
# <b> "chol" & "thalach" and  "fps" and "oldpeak" </b>have a correlation coefficient of "-0.069" and "-0.062" which indicates that they have a <b> weak correlation between them. </b>

# %% [markdown]
# <b>Therefore, we select the main features on the bases of correlation as ['slope','oldpeak','thalach','cp','exang'] </b>

# %%
sns.pairplot(df_heart[['slope','oldpeak','thalach','cp','exang','target']],hue='target')

# %% [markdown]
# <b> The pairs of features "slope" & "thalach", "exang" & "oldpeak", "Thalach" & "cp" have strong correlation between them. </b>

# %% [markdown]
# ##### Correlation comparison with targets can help us figure out the main features. These features playes major role in figuring out our target variable over the testing dataset.
